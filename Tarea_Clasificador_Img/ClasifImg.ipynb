# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
from PIL import Image,ImageOps,ImageFilter
import os
import math
import json
from io import StringIO
import skimage as ski
from skimage import data, io, filters, color

# %%
Fg = os.path.join("foto.jpg")

# %%
Figura = Image.open(Fg)
Figura
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=322x244 at 0x25F9865D6A0>

# %%
Figura_bw = Figura.convert("LA")
Figura_bw
# Out:
# <PIL.Image.Image image mode=LA size=322x244 at 0x25F990FDA58>
